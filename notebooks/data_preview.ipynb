# %%
import pandas as pd
import os

# Navigate from /notebooks to /data/raw
data_path = os.path.join('..', 'data', 'raw', 'diabetes_obesity_raw.parquet')

# Load and display
if os.path.exists(data_path):
    df = pd.read_parquet(data_path, engine='fastparquet')
    
    # Show summary stats for the meeting
    print(f"✅ Dataset Loaded Successfully")
    print(f"Rows: {df.shape[0]} | Columns: {df.shape[1]}")
    
    # Display the interactive table
    display(df.head(10))
else:
    print("❌ Data file not found. Did you run 'python src/fetch_data.py' first?")
# Out:
# ✅ Dataset Loaded Successfully
# Rows: 5075 | Columns: 46
#    Id_diabetes IndicatorCode_diabetes SpatialDimType_diabetes country_code  \
# 0      1491844            NCD_GLUC_04                 COUNTRY          COD
# 1      1496684            NCD_GLUC_04                 COUNTRY          TLS
# 2      1498813            NCD_GLUC_04                 COUNTRY          MHL
# 3      1506910            NCD_GLUC_04                 COUNTRY          CHN
# 4      1507927            NCD_GLUC_04                 COUNTRY          DMA
# 5      1507956            NCD_GLUC_04                 COUNTRY          ITA
# 6      1512005            NCD_GLUC_04                 COUNTRY          MLI
# 7      1512211            NCD_GLUC_04                 COUNTRY          AUT
# 8      1514698            NCD_GLUC_04                 COUNTRY          ATG
# 9      1514846            NCD_GLUC_04                 COUNTRY          COL
#
#   TimeDimType_diabetes ParentLocationCode_diabetes   ParentLocation  \
# ...
